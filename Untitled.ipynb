# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
% matplotlib inline
customer=pd.read_csv('customer_data.csv')

customer['gender']= np.where((customer['gender'])=='Male',1, 0)

# %%
customer.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG       0              0     Yes         No       1           No
# 1  5575-GNVDE       1              0      No         No      34          Yes
# 2  3668-QPYBK       1              0      No         No       2          Yes
# 3  7795-CFOCW       1              0      No         No      45           No
# 4  9237-HQITU       0              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0  No phone service             DSL             No  ...                No
# 1                No             DSL            Yes  ...               Yes
# 2                No             DSL            Yes  ...                No
# 3  No phone service             DSL            Yes  ...               Yes
# 4                No     Fiber optic             No  ...                No
#
# ...

# %%
customer['Partner'] = customer['Partner'].apply(lambda x: 0 if x=='No' else 1)

# %%
customer['Dependents'] = customer['Dependents'].apply(lambda x: 0 if x=='No' else 1)

# %%
customer['PhoneService'] = customer['PhoneService'].apply(lambda x: 0 if x=='No' else 1)

# %%
customer['OnlineSecurity'] = customer['OnlineSecurity'].apply(lambda x: 0 if x=='No' else 1)

# %%
customer['TechSupport'] = customer['TechSupport'].apply(lambda x: 0 if x=='No' else 1)
customer['StreamingTV'] = customer['StreamingTV'].apply(lambda x: 0 if x=='No' else 1)
customer['OnlineBackup'] = customer['OnlineBackup'].apply(lambda x: 0 if x=='No' else 1)
customer['StreamingMovies'] = customer['StreamingMovies'].apply(lambda x: 0 if x=='No' else 1)
customer['DeviceProtection'] = customer['DeviceProtection'].apply(lambda x: 0 if x=='No' else 1)
customer['PaperlessBilling'] = customer['PaperlessBilling'].apply(lambda x: 0 if x=='No' else 1)
customer['Churn'] = customer['Churn'].apply(lambda x: 0 if x=='No' else 1)
customer['MultipleLines'] = customer['MultipleLines'].apply(lambda x: 1 if x=='Yes' else 0)
customer
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     7590-VHVEG       0              0        1           0       1
# 1     5575-GNVDE       1              0        0           0      34
# 2     3668-QPYBK       1              0        0           0       2
# 3     7795-CFOCW       1              0        0           0      45
# 4     9237-HQITU       0              0        0           0       2
# 5     9305-CDSKC       0              0        0           0       8
# 6     1452-KIOVK       1              0        0           1      22
# 7     6713-OKOMC       0              0        0           0      10
# 8     7892-POOKP       0              0        1           0      28
# 9     6388-TABGU       1              0        0           1      62
# 10    9763-GRSKD       1              0        1           1      13
# 11    7469-LKBCI       1              0        0           0      16
# 12    8091-TTVAX       1              0        1           0      58
# ...

# %%
customer = pd.concat([customer.drop('InternetService',axis=1), pd.get_dummies(customer['InternetService'])],axis=1)
customer = pd.concat([customer.drop('Contract',axis=1), pd.get_dummies(customer['Contract'])],axis=1)
customer = pd.concat([customer.drop('PaymentMethod',axis=1), pd.get_dummies(customer['PaymentMethod'])],axis=1)

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 28 columns):
# customerID                   7043 non-null object
# gender                       7043 non-null int32
# SeniorCitizen                7043 non-null int64
# Partner                      7043 non-null int64
# Dependents                   7043 non-null int64
# tenure                       7043 non-null int64
# PhoneService                 7043 non-null int64
# MultipleLines                7043 non-null int64
# OnlineSecurity               7043 non-null int64
# OnlineBackup                 7043 non-null int64
# DeviceProtection             7043 non-null int64
# TechSupport                  7043 non-null int64
# StreamingTV                  7043 non-null int64
# StreamingMovies              7043 non-null int64
# PaperlessBilling             7043 non-null int64
# MonthlyCharges               7043 non-null float64
# TotalCharges                 7043 non-null object
# ...

# %% [markdown]
# # The number of  churn customers

# %% [markdown]
# I look for the percent between churn and not churn customer. This graph shows that the number of churn customer is less than half of not churn customer.

# %%
customer['Churn'].value_counts().plot('bar')
plt.xlabel('churn type')
plt.ylabel('number of people')
plt.title('churn graph')
plt.show()

# %% [markdown]
# # Churn customer vs not Churn cutsomer by tenure

# %% [markdown]
# Comparing churn and not churn customers by tenure, the graph shows that the customer likely to leave to this company first 10 months, and it slowly down after ten months.

# %%
notchurn_customer=customer[customer['Churn']==0]
churn_data= customer[customer['Churn']==1]
x_notchurn=notchurn_customer['tenure']
y_churn=churn_data['tenure']
fig, ax = plt.subplots()

a_churn_heights, a_churn_bins = np.histogram(x_notchurn)
b_churn_heights, b_churn_bins = np.histogram(y_churn, bins=a_bins)

width = (a_churn_bins[1] - b_churn_bins[0])/3

ax.bar(a_churn_bins[:-1], a_churn_heights, width=width, facecolor='blue',label="Not-Churn")
ax.bar(b_churn_bins[:-1]+width, b_churn_heights, width=width, facecolor='yellow',label="Churn")


plt.xticks(size = 7)
plt.yticks(size = 7)
plt.xlabel('Tenure(months)', size = 7)
plt.ylabel('Number of people', size = 7)
plt.title('churn vs not churn', size = 7)
plt.legend(prop={'size':7})
plt.show()

# %%
churn_data= customer[customer['Churn']==1]
churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1869 entries, 2 to 7041
# Data columns (total 28 columns):
# customerID                   1869 non-null object
# gender                       1869 non-null int32
# SeniorCitizen                1869 non-null int64
# Partner                      1869 non-null int64
# Dependents                   1869 non-null int64
# tenure                       1869 non-null int64
# PhoneService                 1869 non-null int64
# MultipleLines                1869 non-null int64
# OnlineSecurity               1869 non-null int64
# OnlineBackup                 1869 non-null int64
# DeviceProtection             1869 non-null int64
# TechSupport                  1869 non-null int64
# StreamingTV                  1869 non-null int64
# StreamingMovies              1869 non-null int64
# PaperlessBilling             1869 non-null int64
# MonthlyCharges               1869 non-null float64
# TotalCharges                 1869 non-null object
# ...

# %% [markdown]
# # Comparing all services in churn customer

# %% [markdown]
# For all services , the graph shows that high amount of people leaves the company due to phone services than other services.

# %%
churn_DSL=churn_data.customerID[churn_data["DSL"]==1]
churn_Fiber=churn_data.customerID[churn_data["Fiber optic"]==1]
churn_Phone=churn_data.customerID[churn_data["PhoneService"]==1]
churn_onlinesercurity=churn_data.customerID[churn_data["OnlineSecurity"]==1]
churn_onlinebackup=churn_data.customerID[churn_data["OnlineBackup"]==1]
churn_deviceprotect=churn_data.customerID[churn_data["DeviceProtection"]==1]
churn_techsupport=churn_data.customerID[churn_data["TechSupport"]==1]
churn_streamingtv=churn_data.customerID[churn_data["StreamingTV"]==1]
churn_streamingmovies=churn_data.customerID[churn_data["StreamingMovies"]==1]

x_customer=len(customer)
x_DSL=(len(churn_DSL)/float(x_customer))*100
x_Fiber=(len(churn_Fiber)/float(x_customer))*100
x_phone=(len(churn_Phone)/float(x_customer))*100

x_onlinesercurity=(len(churn_onlinesercurity)/float(x_customer))*100
x_onlinebackup=(len(churn_onlinebackup)/float(x_customer))*100
x_deviceprotect=(len(churn_deviceprotect)/float(x_customer))*100
x_techsupport=(len(churn_techsupport)/float(x_customer))*100
x_streamingtv=(len(churn_streamingtv)/float(x_customer))*100
x_streamingmovies=(len(churn_streamingmovies)/float(x_customer))*100



objects = ('DSL', 'Fiber', 'Phone','Online Security', 'Oline Backup', 'Device Protection','Tech Support','Streaming Tv','Streaming Movies')
y_pos = np.arange(len(objects))
performance = [x_DSL,x_Fiber,x_phone,x_onlinesercurity,x_onlinebackup,x_deviceprotect,x_techsupport,x_streamingtv,x_streamingmovies]
 
plt.bar(y_pos, performance, align='center', alpha=0.5)

plt.yticks(size = 7)
plt.xticks(y_pos, objects,size = 6)
plt.ylabel('Percent of people Churn',size = 7)
plt.title('services',size = 7)
plt.show()

# %% [markdown]
# # sernior discount

# %% [markdown]
# The number of churn customer
# The graph shows the demographic of population, younger people are like to sign-up for this comapnay rather than senior.

# %%
x = churn_data[customer["SeniorCitizen"]==1]
y = churn_data[customer["SeniorCitizen"]==0]

x_count=x['tenure']
y_count=y['tenure']
fig, ax = plt.subplots()

a_heights, a_bins = np.histogram(x_count)
b_heights, b_bins = np.histogram(y_count, bins=a_bins)

width = (a_bins[1] - a_bins[0])/3

ax.bar(a_bins[:-1], a_heights, width=width, facecolor='blue',label="Senior")
ax.bar(b_bins[:-1]+width, b_heights, width=width, facecolor='yellow',label="Non-Senior")


plt.xticks(size = 7)
plt.yticks(size = 7)
plt.xlabel('Tenure(months)', size = 7)
plt.ylabel('Number of people', size = 7)
plt.title('senior discount vs Tenure', size = 7)
plt.legend(prop={'size':7})
plt.show()

# %% [markdown]
# # Number of senior and non-senior in term of churn.

# %%
seniorchurn_data= churn_data[churn_data["SeniorCitizen"]==1]
nonseniorchurn_dataone= churn_data[churn_data["SeniorCitizen"]==0]
nonchurn_data_senior= notchurn_customer[notchurn_customer["SeniorCitizen"]==1]
nonchurn_data_nonsenior= notchurn_customer[notchurn_customer["SeniorCitizen"]==0]

x_seniorchurn_data = seniorchurn_data['tenure']
y_nonseniorchurn_dataone = nonseniorchurn_dataone['tenure']

notx_nonchurn_data_senior = nonchurn_data_senior['tenure']
noty_nonchurn_data_nonsenior = nonchurn_data_nonsenior['tenure']


plt.figure()
plt.hist([x_seniorchurn_data,y_nonseniorchurn_dataone,notx_nonchurn_data_senior,noty_nonchurn_data_nonsenior], bins=7, stacked=False ,
         color=["red", "blue", "violet","yellow"],
         label=["churn senior","churn non senior","non churn senior","non churn non senior"],
         normed = True) 
plt.legend()
plt.show()

# %% [markdown]
# # correlation matrix graph on churn data

# %%
corr= churn_data.corr()
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.plot(figsize=(200,100))
plt.show()

# %% [markdown]
# # correlation matrix graph on all data

# %%
corr_all= customer.corr()
sns.heatmap(corr_all, 
        xticklabels=corr_all.columns,
        yticklabels=corr_all.columns)
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.plot(figsize=(200,100))
plt.show()

# %% [markdown]
# # Number of people use fiber internet

# %%
fiberchurn_datamonthly= churn_data[(churn_data["Fiber optic"]==1)&(churn_data["Month-to-month"]==1)]
fiberchurn_dataone= churn_data[(churn_data["Fiber optic"]==1)&(churn_data["One year"]==1)]
fiberchurn_datatwo= churn_data[(churn_data["Fiber optic"]==1)&(churn_data["Two year"]==1)]
notfiberchurn_datamonthly= notchurn_customer[(notchurn_customer["Fiber optic"]==1)&(notchurn_customer["Month-to-month"]==1)]
notfiberchurn_dataone= notchurn_customer[(notchurn_customer["Fiber optic"]==1)&(notchurn_customer["One year"]==1)]
notfiberchurn_datatwo= notchurn_customer[(notchurn_customer["Fiber optic"]==1)&(notchurn_customer["Two year"]==1)]
x_month = fiberchurn_datamonthly['tenure']
y_one_year = fiberchurn_dataone['tenure']
z_two_year= fiberchurn_datatwo['tenure']
notx_month = notfiberchurn_datamonthly['tenure']
noty_one_year = notfiberchurn_dataone['tenure']
notz_two_year= notfiberchurn_datatwo['tenure'] 

plt.figure()
plt.hist([x_month,y_one_year,z_two_year,notx_month,noty_one_year,notz_two_year], bins=7, stacked=False ,
         color=["red", "blue", "violet","yellow","orange","green"],
         label=["churn month to month","churn one year","churn two year","not churn month to month","not churn one year","not churn two year"],
         normed = True) 
plt.legend()
plt.show()
